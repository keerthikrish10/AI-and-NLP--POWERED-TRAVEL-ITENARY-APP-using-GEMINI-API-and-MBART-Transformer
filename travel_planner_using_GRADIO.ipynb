# %%
pip install gradio google-generativeai
# Out:
# Collecting gradioNote: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~pencv-python (C:\Users\KEERTHI KRISHANA\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python (C:\Users\KEERTHI KRISHANA\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python (C:\Users\KEERTHI KRISHANA\AppData\Roaming\Python\Python311\site-packages)
#     WARNING: Ignoring invalid distribution ~pencv-python (C:\Users\KEERTHI KRISHANA\AppData\Roaming\Python\Python311\site-packages)
#     WARNING: Ignoring invalid distribution ~pencv-python (C:\Users\KEERTHI KRISHANA\AppData\Roaming\Python\Python311\site-packages)
#     WARNING: Ignoring invalid distribution ~pencv-python (C:\Users\KEERTHI KRISHANA\AppData\Roaming\Python\Python311\site-packages)
#     WARNING: Ignoring invalid distribution ~pencv-python (C:\Users\KEERTHI KRISHANA\AppData\Roaming\Python\Python311\site-packages)
#     WARNING: Ignoring invalid distribution ~pencv-python (C:\Users\KEERTHI KRISHANA\AppData\Roaming\Python\Python311\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-cloud-auth 0.1.3 requires pydantic<2.0, but you have pydantic 2.7.4 which is incompatible.
# s3fs 2023.4.0 requires fsspec==2023.4.0, but you have fsspec 2024.6.0 which is incompatible.
# WARNING: Ignoring invalid distribution ~pencv-python (C:\Users\KEERTHI KRISHANA\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python (C:\Users\KEERTHI KRISHANA\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python (C:\Users\KEERTHI KRISHANA\AppData\Roaming\Python\Python311\site-packages)
#   Using cached gradio-4.36.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: google-generativeai in c:\users\keerthi krishana\anaconda3\lib\site-packages (0.6.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from gradio) (22.1.0)
# Requirement already satisfied: altair<6.0,>=4.2.0 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from gradio) (5.2.0)
# Collecting fastapi (from gradio)
#   Using cached fastapi-0.111.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: ffmpy in c:\users\keerthi krishana\anaconda3\lib\site-packages (from gradio) (0.3.2)
# Collecting gradio-client==1.0.1 (from gradio)
#   Using cached gradio_client-1.0.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from gradio) (0.27.0)
# Collecting huggingface-hub>=0.19.3 (from gradio)
#   Using cached huggingface_hub-0.23.4-py3-none-any.whl.metadata (12 kB)
# Collecting importlib-resources<7.0,>=1.3 (from gradio)
#   Using cached importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: jinja2<4.0 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from gradio) (2.1.1)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\keerthi krishana\appdata\roaming\python\python311\site-packages (from gradio) (3.8.1)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from gradio) (1.24.3)
# Requirement already satisfied: orjson~=3.0 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from gradio) (3.9.15)
# Requirement already satisfied: packaging in c:\users\keerthi krishana\anaconda3\lib\site-packages (from gradio) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\keerthi krishana\appdata\roaming\python\python311\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\keerthi krishana\appdata\roaming\python\python311\site-packages (from gradio) (10.1.0)
# Collecting pydantic>=2.0 (from gradio)
#   Using cached pydantic-2.7.4-py3-none-any.whl.metadata (109 kB)
# Requirement already satisfied: pydub in c:\users\keerthi krishana\anaconda3\lib\site-packages (from gradio) (0.25.1)
# Collecting python-multipart>=0.0.9 (from gradio)
#   Using cached python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from gradio) (6.0)
# Collecting ruff>=0.2.2 (from gradio)
#   Using cached ruff-0.4.9-py3-none-win_amd64.whl.metadata (24 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting tomlkit==0.12.0 (from gradio)
#   Using cached tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Using cached typer-0.12.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from gradio) (4.7.1)
# Requirement already satisfied: urllib3~=2.0 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from gradio) (2.2.2)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Using cached uvicorn-0.30.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: fsspec in c:\users\keerthi krishana\anaconda3\lib\site-packages (from gradio-client==1.0.1->gradio) (2023.4.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from gradio-client==1.0.1->gradio) (11.0.3)
# Requirement already satisfied: google-ai-generativelanguage==0.6.4 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from google-generativeai) (0.6.4)
# Requirement already satisfied: google-api-core in c:\users\keerthi krishana\anaconda3\lib\site-packages (from google-generativeai) (2.19.0)
# Requirement already satisfied: google-api-python-client in c:\users\keerthi krishana\anaconda3\lib\site-packages (from google-generativeai) (2.133.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from google-generativeai) (2.25.2)
# Requirement already satisfied: protobuf in c:\users\keerthi krishana\anaconda3\lib\site-packages (from google-generativeai) (4.23.4)
# Requirement already satisfied: tqdm in c:\users\keerthi krishana\anaconda3\lib\site-packages (from google-generativeai) (4.65.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from google-ai-generativelanguage==0.6.4->google-generativeai) (1.23.0)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from altair<6.0,>=4.2.0->gradio) (4.17.3)
# Requirement already satisfied: toolz in c:\users\keerthi krishana\anaconda3\lib\site-packages (from altair<6.0,>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from google-api-core->google-generativeai) (1.63.1)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from google-api-core->google-generativeai) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: anyio in c:\users\keerthi krishana\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (3.5.0)
# Requirement already satisfied: certifi in c:\users\keerthi krishana\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in c:\users\keerthi krishana\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.4)
# Requirement already satisfied: idna in c:\users\keerthi krishana\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (3.4)
# Requirement already satisfied: sniffio in c:\users\keerthi krishana\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\keerthi krishana\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (3.9.0)
# Collecting fsspec (from gradio-client==1.0.1->gradio)
#   Using cached fsspec-2024.6.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Collecting annotated-types>=0.4.0 (from pydantic>=2.0->gradio)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.18.4 (from pydantic>=2.0->gradio)
#   Using cached pydantic_core-2.18.4-cp311-none-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: colorama in c:\users\keerthi krishana\anaconda3\lib\site-packages (from tqdm->google-generativeai) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.0.4)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rich>=10.11.0 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi->gradio)
#   Using cached starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting typing-extensions~=4.0 (from gradio)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting fastapi-cli>=0.0.2 (from fastapi->gradio)
#   Using cached fastapi_cli-0.0.4-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from fastapi->gradio) (5.4.0)
# Collecting email_validator>=2.0.0 (from fastapi->gradio)
#   Using cached email_validator-2.1.2-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Collecting dnspython>=2.0.0 (from email_validator>=2.0.0->fastapi->gradio)
#   Using cached dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.4->google-generativeai) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.4->google-generativeai) (1.62.2)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.18.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.4.8)
# Requirement already satisfied: six>=1.5 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.12.0->fastapi->gradio)
#   Using cached httptools-0.6.1-cp311-cp311-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi->gradio) (0.21.0)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.12.0->fastapi->gradio)
#   Using cached watchfiles-0.22.0-cp311-none-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: mdurl~=0.1 in c:\users\keerthi krishana\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)
# Using cached gradio-4.36.1-py3-none-any.whl (12.3 MB)
# Using cached gradio_client-1.0.1-py3-none-any.whl (318 kB)
# Using cached tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Using cached huggingface_hub-0.23.4-py3-none-any.whl (402 kB)
# Using cached importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Using cached pydantic-2.7.4-py3-none-any.whl (409 kB)
# Using cached pydantic_core-2.18.4-cp311-none-win_amd64.whl (1.9 MB)
# Using cached python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Using cached ruff-0.4.9-py3-none-win_amd64.whl (8.6 MB)
# Using cached semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Using cached typer-0.12.3-py3-none-any.whl (47 kB)
# Using cached uvicorn-0.30.1-py3-none-any.whl (62 kB)
# Using cached fastapi-0.111.0-py3-none-any.whl (91 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached email_validator-2.1.2-py3-none-any.whl (30 kB)
# Using cached fastapi_cli-0.0.4-py3-none-any.whl (9.5 kB)
# Using cached fsspec-2024.6.0-py3-none-any.whl (176 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached starlette-0.37.2-py3-none-any.whl (71 kB)
# Using cached dnspython-2.6.1-py3-none-any.whl (307 kB)
# Using cached httptools-0.6.1-cp311-cp311-win_amd64.whl (55 kB)
# Using cached watchfiles-0.22.0-cp311-none-win_amd64.whl (281 kB)
# Installing collected packages: typing-extensions, tomlkit, shellingham, semantic-version, ruff, python-multipart, importlib-resources, httptools, fsspec, dnspython, annotated-types, watchfiles, uvicorn, starlette, pydantic-core, huggingface-hub, email_validator, typer, pydantic, gradio-client, fastapi-cli, fastapi, gradio
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.7.1
#     Uninstalling typing_extensions-4.7.1:
#       Successfully uninstalled typing_extensions-4.7.1
#   Attempting uninstall: tomlkit
#     Found existing installation: tomlkit 0.11.1
#     Uninstalling tomlkit-0.11.1:
#       Successfully uninstalled tomlkit-0.11.1
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.4.0
#     Uninstalling fsspec-2023.4.0:
#       Successfully uninstalled fsspec-2023.4.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.15.1
#     Uninstalling huggingface-hub-0.15.1:
#       Successfully uninstalled huggingface-hub-0.15.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.8
#     Uninstalling pydantic-1.10.8:
#       Successfully uninstalled pydantic-1.10.8
# Successfully installed annotated-types-0.7.0 dnspython-2.6.1 email_validator-2.1.2 fastapi-0.111.0 fastapi-cli-0.0.4 fsspec-2024.6.0 gradio-4.36.1 gradio-client-1.0.1 httptools-0.6.1 huggingface-hub-0.23.4 importlib-resources-6.4.0 pydantic-2.7.4 pydantic-core-2.18.4 python-multipart-0.0.9 ruff-0.4.9 semantic-version-2.10.0 shellingham-1.5.4 starlette-0.37.2 tomlkit-0.12.0 typer-0.12.3 typing-extensions-4.12.2 uvicorn-0.30.1 watchfiles-0.22.0

# %%
import gradio as gr
import google.generativeai as genai

# %%
def generate_itinerary(destination, num_people, num_days, budget, interests):
  # Securely store your API key (replace with your main key)
  api_key = "AIzaSyD9QmJ1VOSKP1JGWxf0dF0JWiOzoeAo4L0"  # Replace with actual API key
  genai.configure(api_key=api_key)
  model = genai.GenerativeModel('gemini-1.5-pro')

  interest_string = ", ".join(interests) if interests else "no specific interests"
  prompt = f"Suggest a {num_days}-day itinerary for {num_people} people visiting {destination}, with a budget of {budget}. Include interesting tourist spots that cater to {interest_string}."

  response = model.generate_content(prompt)
  return response

# Define Gradio interface elements
interface = gr.Interface(
  fn=generate_itinerary,
  inputs=[
    gr.Textbox(label="Destination"),
    gr.Slider(minimum=1, value=2, label="Number of People"),
    gr.Slider(minimum=1, value=3, label="Number of Days"),
    gr.Radio(choices=["Low", "Medium", "High"], label="Budget"),
    gr.CheckboxGroup(choices=["History", "Food", "Adventure", "Art", "Nightlife"], label="Interests"),
  ],
  outputs="text",
  title="AI-powered Travel Itinerary Generator",
  description="Generate a personalized itinerary based on your travel preferences.",
)

# Launch the Gradio app
interface.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
